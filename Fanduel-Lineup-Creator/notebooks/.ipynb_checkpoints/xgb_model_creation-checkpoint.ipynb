# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, GridSearchCV, KFold, RandomizedSearchCV, train_test_split
import xgboost as xgb
from scipy.stats import uniform, randint
import joblib
import os

pd.set_option("display.max_columns",70)

# %%
#Connect to AWS RDS database
from sqlalchemy import *
from sqlalchemy.orm import Session
from sqlalchemy import Table, Column, String, MetaData, Integer, Float

user = os.environ['RDS_NBA_DATABASE_USER']
password = os.environ['RDS_NBA_DATABASE_PASSWORD']

db_cleaned_data = create_engine(f'postgresql://{user}:{password}@fanduel-lineup-prediction-cleaned-data.cvzkizpca2fx.us-east-1.rds.amazonaws.com')

# %%
base_features = ['FD_pts_scored','location','opponent_id','points_scored','seconds_played','made_field_goals',
                 'attempted_field_goals', 'made_three_point_field_goals', 'attempted_three_point_field_goals',
                 'made_free_throws', 'attempted_free_throws', 'offensive_rebounds','defensive_rebounds', 'assists', 'steals', 
                 'blocks', 'turnovers','game_score', 'rest', 'no_rest', '1_day_rest', '2_day_rest','3_day_rest', '4_day_rest', 
                 '5_day_rest', '5_plus_day_rest','Simple_Rating_System', 'Offensive_Rating', 'Defensive_Rating',
                 'Net_Rating', 'Pace', 'Free_Throw_Rate', '3_Pt_Rate','Turnover_Percentage', 'Offensive_Rebound_Percentage', 
                 'Opponent_EFG','Opponent_Turnover_Percentage', 'Opponent_Defensive_Rebound_Percentage']

player_positions = joblib.load('../joblib_objects/player_positions')
player_slugs = list(player_positions.keys())

# %%
past_7_features = ['points_scored','seconds_played','made_field_goals',
                 'attempted_field_goals', 'made_three_point_field_goals', 'attempted_three_point_field_goals',
                 'made_free_throws', 'attempted_free_throws', 'offensive_rebounds','defensive_rebounds', 'assists', 'steals', 
                 'blocks', 'turnovers','game_score']

def create_dataframe(player):
    
    df = pd.read_sql_table(player,db_cleaned_data,index_col='index')
    
    model_identifier = df['slug'][0]
    
    for feature in past_7_features:
        df[f'{feature}_last_7'] = df[feature].rolling(window=7).mean()
    
        for i in range(len(df)):
            if i < 7:
                df[f'{feature}_last_7'].iloc[i] = df[feature].iloc[0:(i+1)].rolling(i+1).mean().mean()
            else:
                pass
    
    df_totals = df[past_7_features]
    
    for feature in past_7_features:
        df_totals[f'{feature}_average'] = ''
        for i in range(len(df_totals)):
            df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
        else:
            pass
    
    df_totals_columns = [f'{feature}_average' for feature in past_7_features]
    
    df_totals = df_totals[df_totals_columns]

    df_model_features = df
    df_model_features = df_model_features.reset_index()

    df_totals = df_totals.reset_index()


    df_model_features = pd.merge(df_model_features,df_totals,on='index')
    df_model_features = df_model_features.drop('index',axis=1)
    df_model_features = df_model_features.drop('rest',axis=1)
    df_model_features = df_model_features.drop(past_7_features,axis=1)
    
    df_model_features['location'] = df_model_features['location'].replace(['Location.HOME','Location.AWAY'],[0,1])
    
    return df_model_features, player

# %%
player_model_slugs = ['adamsja01',
 'adelde01',
 'akoonde01',
 'alexaky01',
 'alexani01',
 'alkinra01',
 'allengr01',
 'antetko01',
 'antetth01',
 'aytonde01',
 'baglema01',
 'bambamo01',
 'barrerj01',
 'bateske01',
 'bazleda01',
 'bentibe01',
 'bertada02',
 'bitadgo01',
 'blossja01',
 'blueva01',
 'bolbo01',
 'boldejo01',
 'boldema01',
 'bonejo01',
 'bongais01',
 'bowenbr02',
 'bowmaky01',
 'brantja01',
 'brazdig01',
 'bridgmi01',
 'bridgmi02',
 'briscis01',
 'brissos01',
 'broekry01',
 'brownbr01',
 'brownch02',
 'brownma02',
 'brownmo01',
 'browntr01',
 'brunsja01',
 'burtode02',
 'cacokde01',
 'cancavl01',
 'carteje01',
 'cartewe01',
 'caupatr01',
 'chealjo01',
 'cheatzy01',
 'chiozch01',
 'clarkbr01',
 'clarkga01',
 'clavegi01',
 'claxtni01',
 'clemoch01',
 'coffeam01',
 'colsobo01',
 'cookty01',
 'cooleja01',
 'costema01',
 'creekmi01',
 'culveja01',
 'daviste02',
 'davisty01',
 'delgaan01',
 'derrima01',
 'diallha01',
 'divindo01',
 'doncilu01',
 'dortlu01',
 'doumbse01',
 'doylemi01',
 'drewla02',
 'duvaltr01',
 'eddieja01',
 'edwarca01',
 'edwarvi01',
 'eubandr01',
 'evansja02',
 'evansje01',
 'fallta01',
 'farmajo01',
 'fernabr01',
 'frazime01',
 'frazimi01',
 'fredeji01',
 'gabriwe01',
 'gaffoda01',
 'garinpa01',
 'garlada01',
 'garrebi01',
 'gbinimi01',
 'gilesha01',
 'gilgesh01',
 'goodwbr01',
 'grahade01',
 'grantdo01',
 'grayjo01',
 'greenja02',
 'gudurma01',
 'guyky01',
 'hachiru01',
 'hallde01',
 'halldo01',
 'hannadu01',
 'harpeja01',
 'harpeju01',
 'harrima01',
 'harteis01',
 'hayesja02',
 'hayesni01',
 'hearnre01',
 'hernade01',
 'herroty01',
 'herveke01',
 'highsha01',
 'hilljo01',
 'hoardja01',
 'holidaa01',
 'hopsosc01',
 'hortota01',
 'howarwi01',
 'huertke01',
 'humphis01',
 'huntede01',
 'hunterj01',
 'huntevi01',
 'hutchch01',
 'ingraan01',
 'jacksaa01',
 'jacksfr01',
 'jacksja02',
 'jackspi01',
 'jamesju01',
 'jeffeam01',
 'jeffrda01',
 'jeromty01',
 'johnsal02',
 'johnsbj01',
 'johnsca02',
 'johnske04',
 'johnsom01',
 'jonesda02',
 'jonesje01',
 'kabenmf01',
 'kiddst01',
 'kingge03',
 'kinglo02',
 'knoxke01',
 'konchjo01',
 'kurucro01',
 'langfro01',
 'lawvi01',
 'lecquja01',
 'littlna01',
 'loftoza01',
 'loydjo01',
 'lucasjo02',
 'lucaska01',
 'machasc01',
 'maconda01',
 'macurjp01',
 'mannte01',
 'martica02',
 'martico01',
 'martije02',
 'martike03',
 'matenya01',
 'mathega01',
 'mathima01',
 'mccalta01',
 'mccreer01',
 'mcdanja01',
 'mckintr01',
 'mclaujo01',
 'mellini01',
 'meltode01',
 'metuch01',
 'mikaer01',
 'millsel01',
 'miltosh01',
 'mokokad01',
 'montelu01',
 'moonema01',
 'moorebe01',
 'moranja01',
 'morgaju01',
 'morrija01',
 'muldemy01',
 'munfoxa02',
 'musadz01',
 'mykhasv01',
 'naderab01',
 'nealga01',
 'newmama01',
 'norveza01',
 'novakst01',
 'nowelja01',
 'ntilila01',
 'nunnaja01',
 'nunnke01',
 'ojelese01',
 'okafoem01',
 'okoboel01',
 'okogijo01',
 'okpalkz01',
 'onealro01',
 'onimi01',
 'onuakar01',
 'onuakch01',
 'osmande01',
 'owensta01',
 'paigema01',
 'pargoje01',
 'pascher01',
 'pasecan01',
 'pattela01',
 'pattoju01',
 'paulbr01',
 'pelleno01',
 'perkike01',
 'perralo01',
 'peteral01',
 'pinsoth01',
 'poirivi01',
 'pondequ01',
 'pondssh01',
 'poolejo01',
 'porteke02',
 'portemi01',
 'pulleja01',
 'purviro01',
 'qizh01',
 'rabbiv01',
 'rathaxa01',
 'reavejo02',
 'reddica01',
 'reedda01',
 'reidna01',
 'reynoca01',
 'robinde01',
 'robindu01',
 'robinje01',
 'robinju01',
 'robinmi01',
 'robyis01',
 'samanlu01',
 'sampsbr01',
 'sampsja02',
 'sandela01',
 'schofad01',
 'sextoco01',
 'shamela01',
 'shayoma01',
 'siberjo01',
 'silasxa01',
 'silvach01',
 'simmobe01',
 'simmoko01',
 'simonan01',
 'smailal01',
 'smithde03',
 'smithjo03',
 'smithzh01',
 'spaldra01',
 'spellom01',
 'splitti01',
 'stephdj01',
 'stockda01',
 'stokeja01',
 'stonedi01',
 'stoneju01',
 'strusma01',
 'sumneed01',
 'swanica01',
 'tatumja01',
 'tavarwa01',
 'teaguma01',
 'teodomi01',
 'terreja01',
 'terryem01',
 'theisda01',
 'thomakh01',
 'thomama02',
 'thornsi01',
 'thybuma01',
 'tobeymi01',
 'toscaju01',
 'toupaax01',
 'trentga02',
 'trieral01',
 'tuckera01',
 'udohek01',
 'vandeja01',
 'vasqugr01',
 'vincega01',
 'wadede01',
 'wagnemo01',
 'walkelo01',
 'wallaty01',
 'waltode01',
 'wanambr01',
 'warneja01',
 'washbju01',
 'washipj01',
 'watanyu01',
 'watertr01',
 'watsopa01',
 'weartr01',
 'weathqu01',
 'webbja01',
 'welshth01',
 'whitean01',
 'whiteco01',
 'whitede01',
 'wileyja01',
 'wilkida02',
 'willicj01',
 'willigr01',
 'willijo04',
 'willike04',
 'willima05',
 'willini01',
 'willire02',
 'williro04',
 'willizi01',
 'wilsodj01',
 'wilsoja02',
 'woltena01',
 'wrighju02',
 'yabusgu01',
 'youngtr01',
 'zizican01']

# %%
X_features = ['location', 'opponent_id', 'no_rest', '1_day_rest','2_day_rest', '3_day_rest', '4_day_rest', '5_day_rest',
       '5_plus_day_rest', 'Simple_Rating_System', 'Offensive_Rating',
       'Defensive_Rating', 'Net_Rating', 'Pace', 'Free_Throw_Rate','3_Pt_Rate', 'Turnover_Percentage', 'Offensive_Rebound_Percentage',
       'Opponent_EFG', 'Opponent_Turnover_Percentage','Opponent_Defensive_Rebound_Percentage', 'points_scored_last_7',
       'seconds_played_last_7', 'made_field_goals_last_7','attempted_field_goals_last_7', 'made_three_point_field_goals_last_7',
       'attempted_three_point_field_goals_last_7', 'made_free_throws_last_7','attempted_free_throws_last_7', 'offensive_rebounds_last_7',
       'defensive_rebounds_last_7', 'assists_last_7', 'steals_last_7','blocks_last_7', 'turnovers_last_7', 'game_score_last_7',
       'points_scored_average', 'seconds_played_average','made_field_goals_average', 'attempted_field_goals_average',
       'made_three_point_field_goals_average','attempted_three_point_field_goals_average', 'made_free_throws_average',
       'attempted_free_throws_average', 'offensive_rebounds_average','defensive_rebounds_average', 'assists_average', 'steals_average',
       'blocks_average', 'turnovers_average', 'game_score_average']

for player in player_model_slugs:
    
    df_model_features, player = create_dataframe(player)
    
    try:
        y = df_model_features['FD_pts_scored'].values.reshape(-1,1).flatten()

        X = df_model_features[X_features]
        X = MinMaxScaler().fit_transform(X)

        X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

        xgb_search_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42, tree_method='gpu_hist')
        
        search_params = { "colsample_bytree": uniform(0.7, 0.3),
                    "gamma": uniform(0, 1),
                    "learning_rate": uniform(0.03, 0.3), # default 0.1 
                    "max_depth": randint(2, 6), # default 3
                    "n_estimators": randint(100, 150), # default 100
                    "subsample": uniform(0.9, 0.4),
                    "reg_lambda": uniform(0.1, 20),
                    "scale_pos_weight": randint(1, 5)
                }
        search = RandomizedSearchCV(xgb_search_model, param_distributions=search_params, random_state=42, n_iter=400, cv=8, verbose=1, n_jobs=8, return_train_score=True)

        search.fit(X_train, y_train)
        
        top_rank = np.flatnonzero(search.cv_results_['rank_test_score'] == 1)[0]
        optimized_params = search.cv_results_['params'][top_rank]
        
        xgb_model = xgb.XGBRegressor(objective='reg:squarederror',**optimized_params)
        
        xgb_model.fit(X_train,y_train)
        
        joblib.dump(xgb_model,f'../models/{player}_model.dat')
        
    except Exception as e: 
        pass
# Out:
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=8)]: Done 516 tasks      | elapsed:   21.4s
# [Parallel(n_jobs=8)]: Done 1283 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=8)]: Done 2599 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.5min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 997 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=8)]: Done 1583 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 2638 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.3min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 1028 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=8)]: Done 1654 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 2475 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.9min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 704 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=8)]: Done 1349 tasks      | elapsed:   48.6s
# [Parallel(n_jobs=8)]: Done 2301 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.2min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 617 tasks      | elapsed:   16.0s
# [Parallel(n_jobs=8)]: Done 1368 tasks      | elapsed:   39.9s
# [Parallel(n_jobs=8)]: Done 2277 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.7min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 1389 tasks      | elapsed:   47.0s
# [Parallel(n_jobs=8)]: Done 2458 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.9min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 1028 tasks      | elapsed:   50.3s
# [Parallel(n_jobs=8)]: Done 1654 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 2573 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 590 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=8)]: Done 1152 tasks      | elapsed:   38.4s
# [Parallel(n_jobs=8)]: Done 2155 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=8)]: Done 1324 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=8)]: Done 2174 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.2min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 668 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=8)]: Done 1350 tasks      | elapsed:   55.7s
# [Parallel(n_jobs=8)]: Done 1872 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3122 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.6min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=8)]: Done 713 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=8)]: Done 1550 tasks      | elapsed:   35.8s
# [Parallel(n_jobs=8)]: Done 2672 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.2min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 645 tasks      | elapsed:   15.0s
# [Parallel(n_jobs=8)]: Done 1388 tasks      | elapsed:   40.7s
# [Parallel(n_jobs=8)]: Done 2296 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.6min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 617 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=8)]: Done 1324 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=8)]: Done 1972 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.5min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 516 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=8)]: Done 1148 tasks      | elapsed:   51.5s
# [Parallel(n_jobs=8)]: Done 1880 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=8)]: Done 1358 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=8)]: Done 2346 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.5min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 577 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=8)]: Done 1050 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=8)]: Done 1748 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 2690 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  3.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=8)]: Done 1285 tasks      | elapsed:   55.0s
# [Parallel(n_jobs=8)]: Done 1946 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.7min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 645 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=8)]: Done 1388 tasks      | elapsed:   36.2s
# [Parallel(n_jobs=8)]: Done 2362 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.4min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 608 tasks      | elapsed:   23.4s
# [Parallel(n_jobs=8)]: Done 1160 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=8)]: Done 1826 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 2964 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   15.5s
# [Parallel(n_jobs=8)]: Done 1236 tasks      | elapsed:   38.9s
# [Parallel(n_jobs=8)]: Done 2232 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 691 tasks      | elapsed:   17.9s
# [Parallel(n_jobs=8)]: Done 1336 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=8)]: Done 2255 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 603 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=8)]: Done 1321 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=8)]: Done 2252 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=8)]: Done 1382 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=8)]: Done 2560 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.2min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 790 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=8)]: Done 1256 tasks      | elapsed:   41.7s
# [Parallel(n_jobs=8)]: Done 2431 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.1min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 617 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=8)]: Done 1448 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=8)]: Done 2600 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  39 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=8)]: Done 803 tasks      | elapsed:   24.7s
# [Parallel(n_jobs=8)]: Done 1136 tasks      | elapsed:   38.3s
# [Parallel(n_jobs=8)]: Done 1928 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=8)]: Done 3097 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 668 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=8)]: Done 1480 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=8)]: Done 2560 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.5min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 608 tasks      | elapsed:   23.8s
# [Parallel(n_jobs=8)]: Done 1142 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=8)]: Done 1748 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3105 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=8)]: Done 1388 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=8)]: Done 2489 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 608 tasks      | elapsed:   23.7s
# [Parallel(n_jobs=8)]: Done 1248 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=8)]: Done 2261 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.8min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=8)]: Done 1382 tasks      | elapsed:   45.2s
# [Parallel(n_jobs=8)]: Done 2468 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.9min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 617 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=8)]: Done 1388 tasks      | elapsed:   48.3s
# [Parallel(n_jobs=8)]: Done 2431 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=8)]: Done 3185 out of 3200 | elapsed:  2.0min remaining:    0.5s
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.0min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  37 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=8)]: Done 801 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=8)]: Done 1356 tasks      | elapsed:   55.5s
# [Parallel(n_jobs=8)]: Done 1880 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=8)]: Done 3151 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.6min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=8)]: Done 736 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=8)]: Done 1474 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=8)]: Done 2120 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  1.9min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 617 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=8)]: Done 1327 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=8)]: Done 2495 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.5min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=8)]: Done 997 tasks      | elapsed:   47.1s
# [Parallel(n_jobs=8)]: Done 1610 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=8)]: Done 2520 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=8)]: Done 3200 out of 3200 | elapsed:  2.6min finished
# C:\Users\Eric\anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# <ipython-input-4-789e38ad6129>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'] = ''
# <ipython-input-4-789e38ad6129>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_totals[f'{feature}_average'].iloc[i] = df_totals[feature].iloc[0:i+1].mean()
# Fitting 8 folds for each of 400 candidates, totalling 3200 fits
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  35 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=8)]: Done 589 tasks      | elapsed:   19.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-50c675d141d9> in <module>
#      36         search = RandomizedSearchCV(xgb_search_model, param_distributions=search_params, random_state=42, n_iter=400, cv=8, verbose=1, n_jobs=8, return_train_score=True)
#      37
# ---> 38         search.fit(X_train, y_train)
#      39
#      40         top_rank = np.flatnonzero(search.cv_results_['rank_test_score'] == 1)[0]
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1527     def _run_search(self, evaluate_candidates):
#    1528         """Search n_iter candidates from param_distributions"""
# -> 1529         evaluate_candidates(ParameterSampler(
#    1530             self.param_distributions, self.n_iter,
#    1531             random_state=self.random_state))
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
